# %%
import pandas as pd

df = pd.read_csv('../data/personas_eda.csv')

df.head()   
print("")
df.info()
print("")
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15 non-null     int64
#  1   edad             15 non-null     int64
#  2   genero           15 non-null     str
#  3   educacion        15 non-null     str
#  4   ingreso_mensual  15 non-null     int64
#  5   horas_trabajo    15 non-null     int64
#  6   ciudad           15 non-null     str
# dtypes: int64(4), str(3)
# memory usage: 972.0 bytes
#               id       edad  ingreso_mensual  horas_trabajo
# count  15.000000  15.000000     1.500000e+01      15.000000
# mean    8.000000  34.266667     7.293333e+05      41.533333
# std     4.472136   8.746156     2.091639e+05       5.705469
# min     1.000000  23.000000     4.500000e+05      30.000000
# 25%     4.500000  27.500000     5.600000e+05      38.500000
# 50%     8.000000  32.000000     7.000000e+05      40.000000
# ...
