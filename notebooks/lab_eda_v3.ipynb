# %%
import pandas as pd

# Cargar dataset
df = pd.read_csv("../data/personas_eda.csv")

#Transformación: reemplazar ciudad
df["ciudad"] = df["ciudad"].replace("Viña del Mar", "Valparaiso")

# Verificar cambio
print(df)
# Out:
#     id  edad     genero      educacion  ingreso_mensual  horas_trabajo  \
# 0    1    25   Femenino  Universitaria           850000             40
# 1    2    32  Masculino        Tecnica           650000             45
# 2    3    28   Femenino  Universitaria           920000             38
# 3    4    45  Masculino          Media           500000             50
# 4    5    36   Femenino        Tecnica           700000             42
# 5    6    29  Masculino  Universitaria          1100000             40
# 6    7    52   Femenino          Media           480000             35
# 7    8    41  Masculino        Tecnica           750000             44
# 8    9    23   Femenino  Universitaria           600000             30
# 9   10    38  Masculino  Universitaria          1050000             48
# 10  11    27   Femenino        Tecnica           680000             40
# 11  12    34  Masculino          Media           520000             46
# ...
